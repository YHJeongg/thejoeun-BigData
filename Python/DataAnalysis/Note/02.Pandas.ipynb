# %%
import pandas as pd

# %%
dict_data = {
    'c0' : [1,2,3],
    'c1' : [4,5,6],
    'c2' : [7,8,9],
    'c3' : [10,11,12]
}

dict_data
# Out:
# {'c0': [1, 2, 3], 'c1': [4, 5, 6], 'c2': [7, 8, 9], 'c3': [10, 11, 12]}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    c0  c1  c2  c3
# 0   1   4   7  10
# 1   2   5   8  11
# 2   3   6   9  12

# %%
# List
df = pd.DataFrame([
    [15, '남', '덕영중'],
    [17, '여', '수리중'],
    ],
    index = ['준서', '예은'],
    columns = ['나이', '성별', '학교']
)

df
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
print(df.index)
print(df.columns)
# Out:
# Index(['준서', '예은'], dtype='object')
# Index(['나이', '성별', '학교'], dtype='object')

# %%
# Index를 학생1, 학생2로 변경
df.index = ['학생1', '학생2']
df
# Out:
#      나이 성별   학교
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# 컬럼을 연령, 남녀, 소속으로 변경
df.columns = ['연령', '남녀', '소속']
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %% [markdown]
# ### 필요한 부분만 수정하기

# %%
df.rename(columns={'나이':'연령'}, inplace=True)
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# 준서를 학생1로 변경하기
df.rename(index={'준서':'학생1'}, inplace=True)
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# List를 통하여 DataFrame 제작후 index와 Column 이름 변경하기
df = pd.DataFrame([
    [90,98,85,100],
    [80,89,95,90],
    [70,95,100,90]
    ],
    index = ['서준','우현','인아'],
    columns = ['수학','영어','음악','체육']
)

df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df = pd.DataFrame({
    '서준' : [90,98,85,100],
    '우현' : [80,89,95,90],
    '인아' : [70,95,100,90]
    },
).T
df.columns = ['수학','영어','음악','체육']
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# df의 index가 우현과 인아인 2개 행을 한꺼번에 삭제
df3 = df.copy()
df3.drop(['우현','인아'], axis=0, inplace=True)
df3
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
# df4의 수학 1개 열을 삭제
df4 = df.copy()
df4.drop(['수학'], axis=1, inplace=True)
df4
# Out:
#     영어   음악   체육
# 서준  98   85  100
# 우현  89   95   90
# 인아  95  100   90

# %%
# df5의 영어와 음악 2개열을 삭제
df5 = df.copy()
df5.drop(['영어','음악'], axis=1, inplace=True)
df5
# Out:
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %% [markdown]
# ### 행과 열을 이용한 데이터 선택
# 1) 데이터프레임 생성 및 특정 위치 찾기

# %%
exam_data = {
    '수학':[90,80,70], 
    '영어':[98,89,95],
    '음악':[85,95,100], 
    '체육':[100,90,90], 
    '이름': ['서준','우현','인아'] 
}
exam_data
# Out:
# {'수학': [90, 80, 70],
#  '영어': [98, 89, 95],
#  '음악': [85, 95, 100],
#  '체육': [100, 90, 90],
#  '이름': ['서준', '우현', '인아']}

# %%
df = pd.DataFrame(exam_data)
df
# Out:
#    수학  영어   음악   체육  이름
# 0  90  98   85  100  서준
# 1  80  89   95   90  우현
# 2  70  95  100   90  인아

# %%
# index 만들기
df.set_index('이름', inplace=True)
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 서준의 음악, 체육 점수만 출력
df.loc['서준',['음악','체육']]
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
df.iloc[0,[2,3]]
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %% [markdown]
# ### 데이터 변경하기

# %%
df['국어'] = [10,20,30]
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  10
# 우현  80  89   95   90  20
# 인아  70  95  100   90  30

# %%
# 철수란 학생의 점수는 10, 20, 30, 40, 50 으로 추가하기
df.loc['철수'] = [10,20,30,40,50]
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  10
# 우현  80  89   95   90  20
# 인아  70  95  100   90  30
# 철수  10  20   30   40  50

# %%
# 영희의 점수는 인아와 동일하다 데이터 추가하기
df.loc['영희'] = df.loc['인아']
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  10
# 우현  80  89   95   90  20
# 인아  70  95  100   90  30
# 철수  10  20   30   40  50
# 영희  70  95  100   90  30

# %%
# 서준의 체육 점수를 80으로 변경하기
df.loc['서준','체육'] = 80
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  10
# 우현  80  89   95  90  20
# 인아  70  95  100  90  30
# 철수  10  20   30  40  50
# 영희  70  95  100  90  30

# %%
# 서준의 음악과 체육 점수를 50점으로 변경하기
df.loc['서준',['음악','체육']] = 50
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   50  50  10
# 우현  80  89   95  90  20
# 인아  70  95  100  90  30
# 철수  10  20   30  40  50
# 영희  70  95  100  90  30

# %%
# 서준의 음악 점수를 100점 체육점수를 50점으로 변경하기
df.loc['서준',['음악','체육']] = [100,50]
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98  100  50  10
# 우현  80  89   95  90  20
# 인아  70  95  100  90  30
# 철수  10  20   30  40  50
# 영희  70  95  100  90  30

# %%
df.transpose() # df.T
# Out:
# 이름   서준  우현   인아  철수   영희
# 수학   90  80   70  10   70
# 영어   98  89   95  20   95
# 음악  100  95  100  30  100
# 체육   50  90   90  40   90
# 국어   10  20   30  50   30

# %%
df = pd.DataFrame([
    [1,4,7,10,13],
    [2,5,8,11,14],
    [3,6,9,12,15]
    ],
    index = ['r0','r1','r2'],
    columns = ['c0','c1','c2','c3','c4']
)

df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 인덱스 재설정
new_index = ['r0','r1','r2','r3','r4']
ndf = df.reindex(new_index, fill_value=0)
ndf
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
ndf = df.reset_index()
ndf
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 인덱스 정렬하기
df.sort_index(ascending=False)
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
# c1을 기준으로 내림차순 정렬후 바로 적용하기
df.sort_values(by='c1', ascending=False)
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %% [markdown]
# ---
# ### DataFrame 연산

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: pandas>=0.25 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/jyh/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import seaborn as sns

# %%
titaic = sns.load_dataset('titanic')
titaic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# titanic에서 age와 fare부분만 발췌하여 df라는 dataframe 만들기
df = pd.DataFrame(
    [titaic['age'],
    titaic['fare']]
).T
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
# 모든 컬럼을 10씩 증가하여 addition이라는 dataframe 생성하기
addition = df + 10 # df.add(10)
addition.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
# addition과 df의 차이를 구하여 subtranction이라는 dataframe 만들기
subtranction = addition - df
subtranction.head()
# Out:
#     age  fare
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0
